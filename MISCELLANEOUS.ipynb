# %% [markdown]
# <a href="https://colab.research.google.com/github/ajinkyajumde/SQL-BASICS/blob/main/MISCELLANEOUS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
The STUDENTS table is described as follows:

# %% [markdown]
# ![STD.png](data:image/png;base64,...)

# %% [markdown]
# Query the Name of any student in STUDENTS who scored higher than  Marks. Order your output by the last three characters of each name. If two or more students both have names ending in the same last three characters (i.e.: Bobby, Robby, etc.), secondary sort them by ascending ID.

# %%
select name from students
where marks>75
order by right(name,3),ID ASC

# %% [markdown]
# ![TRIANGLES.png](data:image/png;base64,...)

# %%
SELECT(
    CASE WHEN (A=B AND B=C AND C=A) THEN 'Equilateral'
WHEN (A=B OR A=C OR B=C) AND (A + B > C AND B+C > A AND C+A > B) THEN     'Isosceles'
WHEN A<>B<>C AND (A + B > C AND B+C > A AND C+A > B) THEN 'Scalene'
ELSE 'Not A Triangle' END)
FROM TRIANGLES
